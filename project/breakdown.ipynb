# %% [markdown]
# # Model One
#
# - 2 Blocks
# - 2 Conv Layers
# - Flatten
# - Learning rate 0.001
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.9899
# - **Final Val Accuracy:** 0.1992
# - **Final Train Loss:** 0.0360
# - **Final Val Loss:** 10.7718

# %% [markdown]
# # Model Two
#
# - 3 Blocks
# - 6 Conv Layers
# - Dropout 0.5
# - Learning rate 0.001
# - Flatten
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.0529
# - **Final Val Accuracy:** 0.0551
# - **Final Train Loss:** 2.9446
# - **Final Val Loss:** 2.9453
# - **Improvement Compared to Base Model (%):**

# %% [markdown]
# # Model Three
#
# - 2 Blocks
# - 2 Conv Layers
# - Batch Normalisation
# - Dropout 0.5
# - GlobalAveragePooling2D
# - Learning rate 0.0001
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.3261
# - **Final Val Accuracy:** 0.3130
# - **Final Train Loss:** 2.1691
# - **Final Val Loss:** 2.2151
# - **Improvement Compared to Base Model (%):**

# %% [markdown]
# # Model Four
#
# - 2 Blocks
# - 2 Conv Layers
# - Batch Normalisation
# - Dropout 0.5
# - GlobalAveragePooling2D
# - Learning rate 0.0001
# - Augementation
# - Epochs 60
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.4312
# - **Final Val Accuracy:** 0.3321
# - **Final Train Loss:** 1.8233
# - **Final Val Loss:** 2.2290
# - **Improvement Compared to Base Model (%):**

# %% [markdown]
# # Model Five
#
# - 4 Blocks
# - 4 Conv Layers
# - Batch Normalisation
# - Dropout 0.5
# - GlobalAveragePooling2D
# - Learning rate 0.001
# - Augementation
# - Epochs 40
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.6811
# - **Final Val Accuracy:** 0.4852
# - **Final Train Loss:** 1.0292
# - **Final Val Loss:** 1.9460
# - **Improvement Compared to Base Model (%):**

# %% [markdown]
# # Model Six
#
# - 6 Blocks
# - 6 Conv Layers
# - Batch Normalisation
# - Dropout 0.5
# - GlobalAveragePooling2D
# - Learning rate 0.001
# - Augementation
# - Epochs 50
#
# ## Stats
#
# - **Total Time (s):**
# - **AVG Epoch Time (s):**
# - **Final Train Accuracy:** 0.8955
# - **Final Val Accuracy:** 0.6690
# - **Final Train Loss:** 0.3382
# - **Final Val Loss:** 1.8402
# - **Improvement Compared to Base Model (%):**
